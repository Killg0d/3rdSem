# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("income.data.csv")

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data
# Out:
#        income  happiness
# 0    3.862647   2.314489
# 1    4.979381   3.433490
# 2    4.923957   4.599373
# 3    3.214372   2.791114
# 4    7.196409   5.596398
# ..        ...        ...
# 493  5.249209   4.568705
# 494  3.471799   2.535002
# 495  6.087610   4.397451
# 496  3.440847   2.070664
# 497  4.530545   3.710193
#
# [498 rows x 2 columns]

# %%
plt.scatter(data['income'] ,data['happiness'])

# %%
cor=data.corr()

cor
# Out:
#              income  happiness
# income     1.000000   0.865634
# happiness  0.865634   1.000000

# %%
from statistics import mean
mean(data['income'])
# Out:
# 4.466902362724138

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
x=data.income
y=data['happiness']

# %%
print(type(x))
print(type(y))
x.shape
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# (498,)

# %%
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)
x.shape
# Out:
# (498, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=2)
X_train.shape
# Out:
# (348, 1)

# %%
X_train=np.array(X_train).reshape(-1,1)
X_train.shape
type(X_train)
# Out:
# numpy.ndarray

# %%
X_test=np.array(X_test).reshape(-1,1)
X_test.shape
# Out:
# (150, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict_train = lr.predict(X_train)

# %%
data.plot(kind='scatter',x='income',y='happiness')
plt.plot(X_train,Y_predict_train,color='red')

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
Y_predict = lr.predict(x)
print(Y_predict.shape)
print(lr.intercept_)
print(lr.coef_)
# Out:
# (498, 1)
# [0.2042704]
# [[0.71382551]]

# %% [markdown]
# from tabulate import tabulate
# All_data = [['SL.No','Training','Testing','Slope','Intercept','Train_MSE','Train_MAE','Train_RMSE','Test_MSE','Test_MAE','Test_RMSE']]
# k=1
#
# for i in np.arange(0.1,1.0,0.1):
#     i=(round(i,1))

# %%
m=0
c=0
L=0.001 #learning rate
epochs = 1000
n=float(len(x))
print(len(x))


for i in range(epochs):
    y_pred = m*x +c #curr prediction
    D_m = (-2/n) * sum(x * (y - y_pred)) #derivatives wrt m
    D_c = (-2/n) * sum(y-y_pred) #derivatives wrt c
    m = m - L * D_m
    c = c - L * D_c
print(m,c)
# Out:
# 498
# [0.72328535] [0.15590119]

# %%
data.plot(kind='scatter',x='income',y='happiness')
Y_pred = m * x + c
print(Y_pred.shape)
plt.plot(x,Y_pred,color='red')
# Out:
# (498, 1)

# %%
data.plot(kind='scatter',x='income',y='happiness')
plt.plot(x,Y_pred,color='red')

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y,Y_pred) 
  
rmse = np.sqrt(mean_squared_error(y, Y_pred)) 
r2 = r2_score(y, Y_pred)
print(rmse)
print(mse)
print(r2)
# Out:
# 0.7166570763124229
# 0.5135973650286699
# 0.7493217544857413
